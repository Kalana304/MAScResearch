# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint, solve_ivp
from scipy.interpolate import interp1d
from scipy.optimize import fsolve
import random
import time

# %matplotlib inline
plt.style.use('seaborn-bright')
# Out:
# /tmp/ipykernel_397246/1633032927.py:10: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-bright')

# %%
# Non-Linear Functions
def f(x, beta, gamma, theta):
    return 1 / (1 + np.exp(-beta * gamma * (x - theta)))

def Fvect(x, **kwargs):
    beta = kwargs.get('beta')
    gamma = kwargs.get('gamma')
    sigma = kwargs.get('sigma')
    theta = kwargs.get('theta')

    vmin = -1 / gamma; vmax = 1 / gamma
    nsteps = 1000
    dv = np.abs(vmax - vmin) / nsteps
    v = np.arange(vmin, vmax, dv)

    if type(x) == np.ndarray and len(x.shape) == 2:
        x = np.repeat(x[:, :, np.newaxis], nsteps, axis=2)

    sigmoid_vals = f(x + v, beta, gamma, theta)
    normal_vals = np.exp(-v ** 2 / (2 * sigma ** 2)) / np.sqrt(2 * np.pi * sigma ** 2)

    return np.sum(dv * sigmoid_vals * normal_vals, axis=-1)

# %%
def SingleNodeModel(x, t, **kwargs):
    gamma = kwargs.get('gamma')
    wee = kwargs.get('wee') / gamma; wie = kwargs.get('wie') / gamma
    wei = kwargs.get('wei') / gamma; wii = kwargs.get('wii') / gamma
    alphaE = kwargs.get('alphaE')
    alphaI = kwargs.get('alphaI')
    Ie0 = kwargs.get('ie0') / gamma; Ii0 = kwargs.get('ii0') / gamma

    ext_kwargs = {'beta': kwargs.get('beta'),
                  'gamma': gamma,
                  'theta': kwargs.get('theta'),
                  'sigma': kwargs.get('sigmaE')
                  }

    inh_kwargs = {'beta': kwargs.get('beta'),
                  'gamma': gamma,
                  'theta': kwargs.get('theta'),
                  'sigma': kwargs.get('sigmaI')
                  }
    dEdt = alphaE * (-x[0] + wee * Fvect(x[0], **ext_kwargs) + wie * Fvect(x[1], **inh_kwargs) + Ie0)
    dIdt = alphaI * (-x[1] + wei * Fvect(x[0], **ext_kwargs) + wii * Fvect(x[1], **inh_kwargs) + Ii0)

    return [dEdt, dIdt]

def HeterogeneityModel(x, t, **options):
    gamma = options.get('gamma')
    wee = options.get('wee') / gamma; wie = options.get('wie') / gamma
    wei = options.get('wei') / gamma; wii = options.get('wii') / gamma
    alphaE = options.get('alphaE'); alphaI = options.get('alphaI')
    Ie0 = options.get('ie0') / gamma; Ii0 = options.get('ii0') / gamma
    noise = options.get('noise'); nVar = options.get('D') / gamma ** 2
    dt = options.get('dt')

    ext_kwargs = {'beta': options.get('beta'),
                  'gamma': gamma,
                  'theta': options.get('theta'),
                  'sigma': options.get('sigmaE')
                  }

    inh_kwargs = {'beta': options.get('beta'),
                  'gamma': gamma,
                  'theta': options.get('theta'),
                  'sigma': options.get('sigmaI')
                  }

    dEdt = alphaE * (-x[0] + wee * Fvect(x[0], **ext_kwargs) + wie * Fvect(x[1], **inh_kwargs) + Ie0) + np.sqrt(2 * nVar * dt) * noise(t) / options.get('Ne')
    dIdt = alphaI * (-x[1] + wei * Fvect(x[0], **ext_kwargs) + wii * Fvect(x[1], **inh_kwargs) + Ii0) + np.sqrt(2 * nVar * dt) * noise(t) / options.get('Ni')

    return [dEdt, dIdt]

# %%
def findFixedPoints(minval = -1, maxval = 1, resolution = 75, init_points = 20, **parameters):
    # Define the Grid variable
    minval = minval / parameters.get('gamma')
    maxval = maxval / parameters.get('gamma')

    # Create a grid for evaluation of the vector field
    x1 = np.linspace(minval, maxval, resolution)
    x2 = np.linspace(minval, maxval, resolution)
    x1, x2 = np.meshgrid(x1, x2)

    # Evaluate the slopes
    gradx1, gradx2 = SingleNodeModel([x1, x2], 0, **parameters)

    # Numerical search of stationary points

    fixed_p = []
    y1 = x1.ravel()
    y2 = x2.ravel()

    sample_points = random.sample(list(np.arange(0, resolution ** 2)), k = init_points)

    for i in sample_points:
        # find a zero
        sol, _, ier, _ = fsolve(lambda y : SingleNodeModel(y, 0, **parameters), [y1[i], y2[i]], full_output=1)

        if ier == 1: # Exclude the cases where fsolve didn't converge
            fixed_p.append(sol)

    fixed_p = np.array(fixed_p).T
    print("Fixed points calculated!")

    return gradx1, gradx2, x1, x2, fixed_p

# %%
def fprime(x, beta, gamma, theta):
    return beta * gamma * np.exp(-beta * gamma * (x - theta)) / ((1 + np.exp(-beta * gamma * (x - theta))) ** 2)

def Fprime(x, **kwargs):
    beta = kwargs.get('beta')
    gamma = kwargs.get('gamma')
    sigma = kwargs.get('sigma')
    theta = kwargs.get('theta')

    vmin = -1 / gamma; vmax = 1 / gamma;
    nsteps = 1000
    dv = np.abs(vmax - vmin) / nsteps
    v = np.arange(vmin, vmax, dv)

    # xConv = 0
    # for n in range(nsteps):
    #     v = vmin + n * dv
    #     xConv = xConv + dv * fprime(x + v, beta, gamma, theta) * \
    #                np.exp(-v ** 2 / (2 * sigma ** 2)) / np.sqrt(2 * np.pi * sigma ** 2)
    # return xConv
    if type(x) == np.ndarray and len(x.shape) == 2:
        x = np.repeat(x[:, :, np.newaxis], nsteps, axis=2)

    sigmoid_vals = fprime(x + v, beta, gamma, theta)
    normal_vals = np.exp(-v ** 2 / (2 * sigma ** 2)) / np.sqrt(2 * np.pi * sigma ** 2)

    return np.sum(dv * sigmoid_vals * normal_vals, axis=-1)

def Jacobian(fixed_points, **parameters):
    eigvals = []
    pointtypes = []

    ext_kwargs = {'beta': parameters['beta'],
                  'gamma': parameters['gamma'],
                  'theta': parameters['theta'],
                  'sigma': parameters['sigmaE']
                  }

    inh_kwargs = {'beta': parameters['beta'],
                  'gamma': parameters['gamma'],
                  'theta': parameters['theta'],
                  'sigma': parameters['sigmaI']
                  }

    # Jacobian Analysis
    for i, (fE, fI) in enumerate(fixed_points):
        J = np.zeros((2, 2))

        J[0,0] = parameters['alphaE'] * (-1 + parameters['wee'] / parameters['gamma'] * Fprime(fE, **ext_kwargs))
        J[0,1] = parameters['alphaE'] * parameters['wie'] / parameters['gamma'] * Fprime(fI, **inh_kwargs)
        J[1,0] = parameters['alphaI'] * parameters['wei'] / parameters['gamma'] * Fprime(fE, **ext_kwargs)
        J[1,1] = parameters['alphaI'] * (-1 + parameters['wii'] / parameters['gamma'] * Fprime(fI, **inh_kwargs))

        # Compute and return the eigenvalues
        evals = np.linalg.eig(J)[0]
        eigvals.append(evals)

        # Analysis
        eigval1 = evals[0]
        eigval2 = evals[1]

        if np.imag(eigval1) == 0:
            if np.real(eigval1) < 0 and np.real(eigval2) < 0:
                print(f"Fixed point at {fE, fI} --> Stable Fixed Point", end = " :: ")
                pointtypes.append('green')
            elif np.real(eigval1) == 0 and np.real(eigval2) <= 0 :
                print(f"Fixed point at {fE, fI} --> Neutral Fixed Point", end = " :: " )
                pointtypes.append('blue')
            elif np.real(eigval1) > 0 and np.real(eigval2) < 0:
                print(f"Fixed point at {fE, fI} --> Saddle Point", end = " :: ")
                pointtypes.append('gold')
            else:
                print(f"Fixed point at {fE, fI} --> Unstable Fixed Point ", end = " :: " )
                pointtypes.append('black')

        else:
            if (np.real(eigval1) < 0) and (np.real(eigval2) < 0) and (np.real(eigval1) == np.real(eigval2)):
                print(f"Fixed point at {fE, fI} --> Stable Spiral Focus Point ", end = " :: " )
                pointtypes.append('teal')
            elif np.real(eigval1) == 0 and np.real(eigval2) <= 0 :
                print(f"Fixed point at {fE, fI} --> Neutral Centre", end = " :: ")
                pointtypes.append('red')
            else:
                print(f"Fixed point at {fE, fI} --> Unstable Spiral Focus", end = " :: ")
                pointtypes.append('indigo')

        print(f"Eigen Values: \u03BB1 = {eigval1 :.3f}  \u03BB2 = {eigval2 :.3f}")

    return eigvals, pointtypes

# %%
# Plotting

def plotVectField(time_, fixed_points, size = (10, 10), init_points = 5, *args, **options):
    locs = args[0]
    grads = args[1]
    minval = args[2] / options['gamma']; maxval = args[3] / options['gamma']

    # Plotting the vector field in the state space (E, I)
    plt.figure(figsize=size)
    plt.quiver(locs[1], locs[0], grads[1], grads[0], pivot='mid', alpha=.8)
    plt.xlim([minval, maxval])
    plt.ylim([minval, maxval])
    plt.xlabel(r'$I$', fontsize=16)
    plt.ylabel(r'$E$', fontsize=16)
    plt.grid()

    # Numerical ODE integration to plot trajectories
    xE = np.random.uniform(minval, maxval, init_points)
    xI = np.random.uniform(minval, maxval, init_points)

    extensemble = np.zeros((init_points, len(time_)))
    inhensemble = np.zeros((init_points, len(time_)))

    for k, y0 in enumerate(zip(xE, xI)):
        # xSolve = odeint(lambda y, t: HeterogeneityModel(y, t, **params), y0, time)
        # extSolve, inhSolve = xSolve.T

        tic = time.time()
        xSolve = solve_ivp(lambda t, y: HeterogeneityModel(y, t, **options), [0, time_[-1]], y0, method='BDF', t_eval=time_, **{'max_step': 0.1})
        extSolve, inhSolve = xSolve['y']
        toc = time.time()
        print(f'Evaluating with random initialization No. {k + 1} --> Execution time: {toc - tic :.3f}s')

        extensemble[k, :] = extSolve
        inhensemble[k, :] = inhSolve

        # Plot the solution in the state space
        plt.plot(inhSolve, extSolve, '-', )

        # Plot the starting point
        plt.scatter(y0[1], y0[0], marker='*', c='r', s=300, label=f"xE = {y0[0]:.3f} xI = {y0[1]:.3f}")

    # Plot the fixed points identified
    plt.scatter(fixed_points[1], fixed_points[0], marker='o', c='k', s=100,
                label="Stationary points")
    plt.legend(loc="upper left")
    plt.title(f"Vector Field Analysis with \u03C3e = {options.get('sigmaE')}mV, \u03C3i = {options.get('sigmaI')}mV, Ie(t) = {options.get('ie0') / options.get('gamma'):.3f}mV")
    plt.show()

    return extensemble, inhensemble

def plotTimeSeries(ext_series, inh_series, time_, size = (10,10)):
    avg_ext = np.mean(ext_series, axis=0)
    avg_inh = np.mean(inh_series, axis=0)

    # Plot the solution in time
    plt.figure(figsize=size)

    plt.subplot(2, 1, 1)
    plt.ylabel(r'$E$'); plt.xlabel(r'$t$')
    plt.xlim([0, time_[-1]])
    plt.plot(time_[45:], avg_ext[45:], '-', label="excitatory")
    plt.title(f'Excitatory Population Dynamics (Avg. over {ext_series.shape[0]} trials)')

    plt.subplot(2, 1, 2)
    plt.ylabel(r'$I$'); plt.xlabel(r'$t$')
    plt.plot(time_[45:], avg_inh[45:], '-', label="inhibitory");
    plt.xlim([0, time_[-1]])
    plt.title(f'Inhibitory Population Dynamics (Avg. over {ext_series.shape[0]} trials)')
    plt.tight_layout()
    plt.show()

# %%
totSim = 250            # 250ms simulation time
dt = 0.1                # Step size

tspan = np.arange(0, totSim, dt)                        # Simulation time array
gausNoise = np.random.normal(0.0, 1.0, len(tspan))      # Creating Gaussian noise array
gausInterp = interp1d(tspan, gausNoise, kind='cubic')   # Look-up table to access the noise points

# %%
Isteps = 250
Imax = 0.25; Imin = -0.25
fixedTrack = []
fixedColors = []

for I in range(Isteps):
    iet = I / Isteps * (Imax - Imin)
    params = {
            'wee': 1.6, 'wie': -4.7, 'wei': 3, 'wii': -0.13,
            'beta': 300, 'gamma': 0.016, 'theta': 0.0,
            'ie0': -0.25 + iet, 'ii0': -0.5,
            'sigmaE': 7.8, 'sigmaI': 16.25,
            'alphaE': 1, 'alphaI': 2,
            'D': 0.001, 'noise': gausInterp, 'dt': dt,
            'Ne': 800, 'Ni': 200
        }

    gradx1, gradx2, x1, x2, fixed_p = findFixedPoints(minval=-1, maxval=1, resolution=75, **params)
    uniqfp = np.array(list(set(map(tuple, np.around(fixed_p, 4).T))))   # Unique fixed points
    eigvals, pointtypes = Jacobian(uniqfp, **params)

    fixedTrack.append(uniqfp)
    fixedColors.append(pointtypes)
# Out:
# /tmp/ipykernel_397246/3131282832.py:3: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-beta * gamma * (x - theta)))
# /tmp/ipykernel_397246/4212436488.py:2: RuntimeWarning: overflow encountered in square
#   return beta * gamma * np.exp(-beta * gamma * (x - theta)) / ((1 + np.exp(-beta * gamma * (x - theta))) ** 2)
# Fixed points calculated!
# Fixed point at (-23.5123, -31.2275) --> Stable Fixed Point :: Eigen Values: λ1 = -1.225  λ2 = -1.783
# Fixed points calculated!
# Fixed point at (-23.3944, -31.2155) --> Stable Fixed Point :: Eigen Values: λ1 = -1.242  λ2 = -1.764
# Fixed points calculated!
# Fixed point at (-23.2768, -31.2029) --> Stable Fixed Point :: Eigen Values: λ1 = -1.261  λ2 = -1.742
# Fixed points calculated!
# Fixed point at (-23.1596, -31.1898) --> Stable Fixed Point :: Eigen Values: λ1 = -1.283  λ2 = -1.718
# Fixed points calculated!
# Fixed point at (-23.0427, -31.1762) --> Stable Fixed Point :: Eigen Values: λ1 = -1.308  λ2 = -1.690
# Fixed points calculated!
# Fixed point at (-22.9262, -31.162) --> Stable Fixed Point :: Eigen Values: λ1 = -1.339  λ2 = -1.655
# Fixed points calculated!
# Fixed point at (-22.8101, -31.1471) --> Stable Fixed Point :: Eigen Values: λ1 = -1.382  λ2 = -1.610
# Fixed points calculated!
# Fixed point at (-22.6943, -31.1317) --> Stable Fixed Point :: Eigen Values: λ1 = -1.468  λ2 = -1.520
# Fixed points calculated!
# Fixed point at (-22.579, -31.1157) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.493+0.110j  λ2 = -1.493-0.110j
# Fixed points calculated!
# Fixed point at (-22.4641, -31.099) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.491+0.160j  λ2 = -1.491-0.160j
# Fixed points calculated!
# Fixed point at (-22.3496, -31.0817) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.490+0.198j  λ2 = -1.490-0.198j
# Fixed points calculated!
# Fixed point at (-22.2356, -31.0637) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.488+0.232j  λ2 = -1.488-0.232j
# Fixed points calculated!
# Fixed point at (-22.122, -31.045) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.486+0.262j  λ2 = -1.486-0.262j
# Fixed points calculated!
# Fixed point at (-22.0089, -31.0256) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.484+0.290j  λ2 = -1.484-0.290j
# Fixed points calculated!
# Fixed point at (-21.8963, -31.0056) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.482+0.317j  λ2 = -1.482-0.317j
# Fixed points calculated!
# Fixed point at (-21.7842, -30.9847) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.480+0.342j  λ2 = -1.480-0.342j
# Fixed points calculated!
# Fixed point at (-21.6726, -30.9632) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.478+0.366j  λ2 = -1.478-0.366j
# Fixed points calculated!
# Fixed point at (-21.5616, -30.9408) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.476+0.390j  λ2 = -1.476-0.390j
# Fixed points calculated!
# Fixed point at (-21.4511, -30.9177) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.474+0.413j  λ2 = -1.474-0.413j
# Fixed points calculated!
# Fixed point at (-21.3412, -30.8938) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.472+0.435j  λ2 = -1.472-0.435j
# Fixed points calculated!
# Fixed point at (-21.2319, -30.8691) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.469+0.457j  λ2 = -1.469-0.457j
# Fixed points calculated!
# Fixed point at (-21.1232, -30.8436) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.467+0.479j  λ2 = -1.467-0.479j
# Fixed points calculated!
# Fixed point at (-21.0151, -30.8173) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.465+0.501j  λ2 = -1.465-0.501j
# Fixed points calculated!
# Fixed point at (-20.9076, -30.7902) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.462+0.522j  λ2 = -1.462-0.522j
# Fixed points calculated!
# Fixed point at (-20.8008, -30.7622) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.460+0.543j  λ2 = -1.460-0.543j
# Fixed points calculated!
# Fixed point at (-20.6947, -30.7333) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.457+0.564j  λ2 = -1.457-0.564j
# Fixed points calculated!
# Fixed point at (-20.5892, -30.7036) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.454+0.585j  λ2 = -1.454-0.585j
# Fixed points calculated!
# Fixed point at (-20.4845, -30.673) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.452+0.606j  λ2 = -1.452-0.606j
# Fixed points calculated!
# Fixed point at (-20.3804, -30.6416) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.449+0.627j  λ2 = -1.449-0.627j
# Fixed points calculated!
# Fixed point at (-20.2771, -30.6092) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.446+0.648j  λ2 = -1.446-0.648j
# Fixed points calculated!
# Fixed point at (-20.1745, -30.576) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.443+0.668j  λ2 = -1.443-0.668j
# Fixed points calculated!
# Fixed point at (-20.0727, -30.5419) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.440+0.689j  λ2 = -1.440-0.689j
# Fixed points calculated!
# Fixed point at (-19.9716, -30.507) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.437+0.709j  λ2 = -1.437-0.709j
# Fixed points calculated!
# Fixed point at (-19.8714, -30.4711) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.434+0.730j  λ2 = -1.434-0.730j
# Fixed points calculated!
# Fixed point at (-19.7719, -30.4344) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.431+0.750j  λ2 = -1.431-0.750j
# Fixed points calculated!
# Fixed point at (-19.6733, -30.3967) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.428+0.771j  λ2 = -1.428-0.771j
# Fixed points calculated!
# Fixed point at (-19.5754, -30.3582) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.425+0.792j  λ2 = -1.425-0.792j
# Fixed points calculated!
# Fixed point at (-19.4784, -30.3188) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.421+0.812j  λ2 = -1.421-0.812j
# Fixed points calculated!
# Fixed point at (-19.3823, -30.2786) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.418+0.833j  λ2 = -1.418-0.833j
# Fixed points calculated!
# Fixed point at (-19.287, -30.2374) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.414+0.854j  λ2 = -1.414-0.854j
# Fixed points calculated!
# Fixed point at (-19.1926, -30.1954) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.411+0.874j  λ2 = -1.411-0.874j
# Fixed points calculated!
# Fixed point at (-19.0991, -30.1526) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.407+0.895j  λ2 = -1.407-0.895j
# Fixed points calculated!
# Fixed point at (-19.0065, -30.1089) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.404+0.916j  λ2 = -1.404-0.916j
# Fixed points calculated!
# Fixed point at (-18.9147, -30.0644) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.400+0.937j  λ2 = -1.400-0.937j
# Fixed points calculated!
# Fixed point at (-18.8239, -30.0191) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.396+0.957j  λ2 = -1.396-0.957j
# Fixed points calculated!
# Fixed point at (-18.734, -29.973) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.393+0.978j  λ2 = -1.393-0.978j
# Fixed points calculated!
# Fixed point at (-18.645, -29.9261) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.389+0.999j  λ2 = -1.389-0.999j
# Fixed points calculated!
# Fixed point at (-18.5569, -29.8784) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.385+1.020j  λ2 = -1.385-1.020j
# Fixed points calculated!
# Fixed point at (-18.4698, -29.8299) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.381+1.041j  λ2 = -1.381-1.041j
# Fixed points calculated!
# Fixed point at (-18.3836, -29.7807) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.377+1.062j  λ2 = -1.377-1.062j
# Fixed points calculated!
# Fixed point at (-18.2984, -29.7308) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.373+1.083j  λ2 = -1.373-1.083j
# Fixed points calculated!
# Fixed point at (-18.2141, -29.6802) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.369+1.104j  λ2 = -1.369-1.104j
# Fixed points calculated!
# Fixed point at (-18.1307, -29.6289) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.365+1.125j  λ2 = -1.365-1.125j
# Fixed points calculated!
# Fixed point at (-18.0483, -29.5769) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.361+1.147j  λ2 = -1.361-1.147j
# Fixed points calculated!
# Fixed point at (-17.9669, -29.5243) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.357+1.168j  λ2 = -1.357-1.168j
# Fixed points calculated!
# Fixed point at (-17.8864, -29.471) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.353+1.189j  λ2 = -1.353-1.189j
# Fixed points calculated!
# Fixed point at (-17.8068, -29.4171) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.349+1.210j  λ2 = -1.349-1.210j
# Fixed points calculated!
# Fixed point at (-17.7282, -29.3627) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.345+1.231j  λ2 = -1.345-1.231j
# Fixed points calculated!
# Fixed point at (-17.6506, -29.3076) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.341+1.253j  λ2 = -1.341-1.253j
# Fixed points calculated!
# Fixed point at (-17.5738, -29.2521) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.336+1.274j  λ2 = -1.336-1.274j
# Fixed points calculated!
# Fixed point at (-17.4981, -29.196) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.332+1.295j  λ2 = -1.332-1.295j
# Fixed points calculated!
# Fixed point at (-17.4233, -29.1394) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.328+1.316j  λ2 = -1.328-1.316j
# Fixed points calculated!
# Fixed point at (-17.3494, -29.0823) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.324+1.338j  λ2 = -1.324-1.338j
# Fixed points calculated!
# Fixed point at (-17.2764, -29.0248) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.319+1.359j  λ2 = -1.319-1.359j
# Fixed points calculated!
# Fixed point at (-17.2044, -28.9668) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.315+1.380j  λ2 = -1.315-1.380j
# Fixed points calculated!
# Fixed point at (-17.1332, -28.9084) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.311+1.402j  λ2 = -1.311-1.402j
# Fixed points calculated!
# Fixed point at (-17.063, -28.8496) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.307+1.423j  λ2 = -1.307-1.423j
# Fixed points calculated!
# Fixed point at (-16.9937, -28.7905) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.302+1.444j  λ2 = -1.302-1.444j
# Fixed points calculated!
# Fixed point at (-16.9253, -28.731) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.298+1.466j  λ2 = -1.298-1.466j
# Fixed points calculated!
# Fixed point at (-16.8578, -28.6712) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.294+1.487j  λ2 = -1.294-1.487j
# Fixed points calculated!
# Fixed point at (-16.7912, -28.611) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.289+1.508j  λ2 = -1.289-1.508j
# Fixed points calculated!
# Fixed point at (-16.7254, -28.5506) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.285+1.529j  λ2 = -1.285-1.529j
# Fixed points calculated!
# Fixed point at (-16.6605, -28.4899) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.281+1.551j  λ2 = -1.281-1.551j
# Fixed points calculated!
# Fixed point at (-16.5965, -28.429) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.276+1.572j  λ2 = -1.276-1.572j
# Fixed points calculated!
# Fixed point at (-16.5333, -28.3678) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.272+1.593j  λ2 = -1.272-1.593j
# Fixed points calculated!
# Fixed point at (-16.471, -28.3065) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.268+1.614j  λ2 = -1.268-1.614j
# Fixed points calculated!
# Fixed point at (-16.4094, -28.2449) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.263+1.636j  λ2 = -1.263-1.636j
# Fixed points calculated!
# Fixed point at (-16.3487, -28.1832) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.259+1.657j  λ2 = -1.259-1.657j
# Fixed points calculated!
# Fixed point at (-16.2888, -28.1213) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.255+1.678j  λ2 = -1.255-1.678j
# Fixed points calculated!
# Fixed point at (-16.2297, -28.0593) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.250+1.699j  λ2 = -1.250-1.699j
# Fixed points calculated!
# Fixed point at (-16.1714, -27.9971) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.246+1.720j  λ2 = -1.246-1.720j
# Fixed points calculated!
# Fixed point at (-16.1138, -27.9349) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.242+1.741j  λ2 = -1.242-1.741j
# Fixed points calculated!
# Fixed point at (-16.0571, -27.8725) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.237+1.762j  λ2 = -1.237-1.762j
# Fixed points calculated!
# Fixed point at (-16.001, -27.8101) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.233+1.783j  λ2 = -1.233-1.783j
# Fixed points calculated!
# Fixed point at (-15.9457, -27.7476) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.229+1.804j  λ2 = -1.229-1.804j
# Fixed points calculated!
# Fixed point at (-15.8912, -27.6851) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.225+1.825j  λ2 = -1.225-1.825j
# Fixed points calculated!
# Fixed point at (-15.8374, -27.6225) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.220+1.845j  λ2 = -1.220-1.845j
# Fixed points calculated!
# Fixed point at (-15.7842, -27.5599) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.216+1.866j  λ2 = -1.216-1.866j
# Fixed points calculated!
# Fixed point at (-15.7318, -27.4974) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.212+1.887j  λ2 = -1.212-1.887j
# Fixed points calculated!
# Fixed point at (-15.6801, -27.4348) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.208+1.908j  λ2 = -1.208-1.908j
# Fixed points calculated!
# Fixed point at (-15.629, -27.3722) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.204+1.928j  λ2 = -1.204-1.928j
# Fixed points calculated!
# Fixed point at (-15.5786, -27.3097) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.199+1.949j  λ2 = -1.199-1.949j
# Fixed points calculated!
# Fixed point at (-15.5289, -27.2472) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.195+1.969j  λ2 = -1.195-1.969j
# Fixed points calculated!
# Fixed point at (-15.4798, -27.1847) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.191+1.990j  λ2 = -1.191-1.990j
# Fixed points calculated!
# Fixed point at (-15.4313, -27.1223) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.187+2.010j  λ2 = -1.187-2.010j
# Fixed points calculated!
# Fixed point at (-15.3835, -27.06) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.183+2.030j  λ2 = -1.183-2.030j
# Fixed points calculated!
# Fixed point at (-15.3362, -26.9977) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.179+2.051j  λ2 = -1.179-2.051j
# Fixed points calculated!
# Fixed point at (-15.2896, -26.9355) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.175+2.071j  λ2 = -1.175-2.071j
# Fixed points calculated!
# Fixed point at (-15.2436, -26.8734) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.171+2.091j  λ2 = -1.171-2.091j
# Fixed points calculated!
# Fixed point at (-15.1981, -26.8114) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.167+2.111j  λ2 = -1.167-2.111j
# Fixed points calculated!
# Fixed point at (-15.1532, -26.7496) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.163+2.131j  λ2 = -1.163-2.131j
# Fixed points calculated!
# Fixed point at (-15.1089, -26.6878) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.159+2.151j  λ2 = -1.159-2.151j
# Fixed points calculated!
# Fixed point at (-15.0652, -26.6262) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.155+2.171j  λ2 = -1.155-2.171j
# Fixed points calculated!
# Fixed point at (-15.0219, -26.5646) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.151+2.191j  λ2 = -1.151-2.191j
# Fixed points calculated!
# Fixed point at (-14.9793, -26.5032) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.147+2.211j  λ2 = -1.147-2.211j
# Fixed points calculated!
# Fixed point at (-14.9371, -26.442) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.143+2.231j  λ2 = -1.143-2.231j
# Fixed points calculated!
# Fixed point at (-14.8955, -26.3809) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.139+2.250j  λ2 = -1.139-2.250j
# Fixed points calculated!
# Fixed point at (-14.8543, -26.3199) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.135+2.270j  λ2 = -1.135-2.270j
# Fixed points calculated!
# Fixed point at (-14.8137, -26.2591) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.132+2.290j  λ2 = -1.132-2.290j
# Fixed points calculated!
# Fixed point at (-14.7735, -26.1985) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.128+2.309j  λ2 = -1.128-2.309j
# Fixed points calculated!
# Fixed point at (-14.7338, -26.138) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.124+2.329j  λ2 = -1.124-2.329j
# Fixed points calculated!
# Fixed point at (-14.6946, -26.0776) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.120+2.348j  λ2 = -1.120-2.348j
# Fixed points calculated!
# Fixed point at (-14.6559, -26.0175) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.116+2.367j  λ2 = -1.116-2.367j
# Fixed points calculated!
# Fixed point at (-14.6176, -25.9575) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.113+2.387j  λ2 = -1.113-2.387j
# Fixed points calculated!
# Fixed point at (-14.5797, -25.8977) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.109+2.406j  λ2 = -1.109-2.406j
# Fixed points calculated!
# Fixed point at (-14.5423, -25.838) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.105+2.425j  λ2 = -1.105-2.425j
# Fixed points calculated!
# Fixed point at (-14.5054, -25.7786) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.102+2.444j  λ2 = -1.102-2.444j
# Fixed points calculated!
# Fixed point at (-14.4688, -25.7193) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.098+2.463j  λ2 = -1.098-2.463j
# Fixed points calculated!
# Fixed point at (-14.4327, -25.6602) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.094+2.482j  λ2 = -1.094-2.482j
# Fixed points calculated!
# Fixed point at (-14.397, -25.6013) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.091+2.501j  λ2 = -1.091-2.501j
# Fixed points calculated!
# Fixed point at (-14.3616, -25.5426) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.087+2.519j  λ2 = -1.087-2.519j
# Fixed points calculated!
# Fixed point at (-14.3267, -25.4841) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.084+2.538j  λ2 = -1.084-2.538j
# Fixed points calculated!
# Fixed point at (-14.2922, -25.4258) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.080+2.557j  λ2 = -1.080-2.557j
# Fixed points calculated!
# Fixed point at (-14.258, -25.3676) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.077+2.575j  λ2 = -1.077-2.575j
# Fixed points calculated!
# Fixed point at (-14.2242, -25.3097) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.073+2.594j  λ2 = -1.073-2.594j
# Fixed points calculated!
# Fixed point at (-14.1908, -25.2519) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.070+2.612j  λ2 = -1.070-2.612j
# Fixed points calculated!
# Fixed point at (-14.1577, -25.1944) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.066+2.631j  λ2 = -1.066-2.631j
# Fixed points calculated!
# Fixed point at (-14.125, -25.137) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.063+2.649j  λ2 = -1.063-2.649j
# Fixed points calculated!
# Fixed point at (-14.0926, -25.0799) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.059+2.668j  λ2 = -1.059-2.668j
# Fixed points calculated!
# Fixed point at (-14.0606, -25.0229) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.056+2.686j  λ2 = -1.056-2.686j
# Fixed points calculated!
# Fixed point at (-14.0289, -24.9662) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.053+2.704j  λ2 = -1.053-2.704j
# Fixed points calculated!
# Fixed point at (-13.9976, -24.9097) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.049+2.722j  λ2 = -1.049-2.722j
# Fixed points calculated!
# Fixed point at (-13.9666, -24.8533) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.046+2.740j  λ2 = -1.046-2.740j
# Fixed points calculated!
# Fixed point at (-13.9359, -24.7972) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.043+2.758j  λ2 = -1.043-2.758j
# Fixed points calculated!
# Fixed point at (-13.9055, -24.7412) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.039+2.776j  λ2 = -1.039-2.776j
# Fixed points calculated!
# Fixed point at (-13.8754, -24.6855) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.036+2.794j  λ2 = -1.036-2.794j
# Fixed points calculated!
# Fixed point at (-13.8456, -24.6299) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.033+2.811j  λ2 = -1.033-2.811j
# Fixed points calculated!
# Fixed point at (-13.8161, -24.5746) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.030+2.829j  λ2 = -1.030-2.829j
# Fixed points calculated!
# Fixed point at (-13.7869, -24.5195) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.026+2.847j  λ2 = -1.026-2.847j
# Fixed points calculated!
# Fixed point at (-13.758, -24.4645) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.023+2.864j  λ2 = -1.023-2.864j
# Fixed points calculated!
# Fixed point at (-13.7294, -24.4098) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.020+2.882j  λ2 = -1.020-2.882j
# Fixed points calculated!
# Fixed point at (-13.7011, -24.3553) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.017+2.899j  λ2 = -1.017-2.899j
# Fixed points calculated!
# Fixed point at (-13.673, -24.3009) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.014+2.917j  λ2 = -1.014-2.917j
# Fixed points calculated!
# Fixed point at (-13.6452, -24.2468) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.011+2.934j  λ2 = -1.011-2.934j
# Fixed points calculated!
# Fixed point at (-13.6177, -24.1929) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.007+2.951j  λ2 = -1.007-2.951j
# Fixed points calculated!
# Fixed point at (-13.5904, -24.1391) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.004+2.969j  λ2 = -1.004-2.969j
# Fixed points calculated!
# Fixed point at (-13.5634, -24.0856) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -1.001+2.986j  λ2 = -1.001-2.986j
# Fixed points calculated!
# Fixed point at (-13.5366, -24.0323) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.998+3.003j  λ2 = -0.998-3.003j
# Fixed points calculated!
# Fixed point at (-13.5101, -23.9791) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.995+3.020j  λ2 = -0.995-3.020j
# Fixed points calculated!
# Fixed point at (-13.4839, -23.9262) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.992+3.037j  λ2 = -0.992-3.037j
# Fixed points calculated!
# Fixed point at (-13.4578, -23.8735) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.989+3.054j  λ2 = -0.989-3.054j
# Fixed points calculated!
# Fixed point at (-13.432, -23.8209) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.986+3.071j  λ2 = -0.986-3.071j
# Fixed points calculated!
# Fixed point at (-13.4065, -23.7686) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.983+3.087j  λ2 = -0.983-3.087j
# Fixed points calculated!
# Fixed point at (-13.3811, -23.7164) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.980+3.104j  λ2 = -0.980-3.104j
# Fixed points calculated!
# Fixed point at (-13.356, -23.6645) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.977+3.121j  λ2 = -0.977-3.121j
# Fixed points calculated!
# Fixed point at (-13.3312, -23.6127) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.975+3.137j  λ2 = -0.975-3.137j
# Fixed points calculated!
# Fixed point at (-13.3065, -23.5611) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.972+3.154j  λ2 = -0.972-3.154j
# Fixed points calculated!
# Fixed point at (-13.2821, -23.5097) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.969+3.170j  λ2 = -0.969-3.170j
# Fixed points calculated!
# Fixed point at (-13.2578, -23.4585) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.966+3.187j  λ2 = -0.966-3.187j
# Fixed points calculated!
# Fixed point at (-13.2338, -23.4075) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.963+3.203j  λ2 = -0.963-3.203j
# Fixed points calculated!
# Fixed point at (-13.21, -23.3567) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.960+3.220j  λ2 = -0.960-3.220j
# Fixed points calculated!
# Fixed point at (-13.1864, -23.306) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.957+3.236j  λ2 = -0.957-3.236j
# Fixed points calculated!
# Fixed point at (-13.1629, -23.2556) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.955+3.252j  λ2 = -0.955-3.252j
# Fixed points calculated!
# Fixed point at (-13.1397, -23.2053) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.952+3.268j  λ2 = -0.952-3.268j
# Fixed points calculated!
# Fixed point at (-13.1167, -23.1553) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.949+3.284j  λ2 = -0.949-3.284j
# Fixed points calculated!
# Fixed point at (-13.0938, -23.1054) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.946+3.301j  λ2 = -0.946-3.301j
# Fixed points calculated!
# Fixed point at (-13.0712, -23.0556) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.944+3.317j  λ2 = -0.944-3.317j
# Fixed points calculated!
# Fixed point at (-13.0487, -23.0061) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.941+3.332j  λ2 = -0.941-3.332j
# Fixed points calculated!
# Fixed point at (-13.0264, -22.9568) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.938+3.348j  λ2 = -0.938-3.348j
# Fixed points calculated!
# Fixed point at (-13.0043, -22.9076) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.935+3.364j  λ2 = -0.935-3.364j
# Fixed points calculated!
# Fixed point at (-12.9824, -22.8586) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.933+3.380j  λ2 = -0.933-3.380j
# Fixed points calculated!
# Fixed point at (-12.9606, -22.8098) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.930+3.396j  λ2 = -0.930-3.396j
# Fixed points calculated!
# Fixed point at (-12.939, -22.7611) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.927+3.411j  λ2 = -0.927-3.411j
# Fixed points calculated!
# Fixed point at (-12.9176, -22.7126) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.925+3.427j  λ2 = -0.925-3.427j
# Fixed points calculated!
# Fixed point at (-12.8964, -22.6643) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.922+3.443j  λ2 = -0.922-3.443j
# Fixed points calculated!
# Fixed point at (-12.8753, -22.6162) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.920+3.458j  λ2 = -0.920-3.458j
# Fixed points calculated!
# Fixed point at (-12.8544, -22.5683) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.917+3.474j  λ2 = -0.917-3.474j
# Fixed points calculated!
# Fixed point at (-12.8336, -22.5205) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.914+3.489j  λ2 = -0.914-3.489j
# Fixed points calculated!
# Fixed point at (-12.813, -22.4729) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.912+3.504j  λ2 = -0.912-3.504j
# Fixed points calculated!
# Fixed point at (-12.7926, -22.4254) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.909+3.520j  λ2 = -0.909-3.520j
# Fixed points calculated!
# Fixed point at (-12.7723, -22.3781) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.907+3.535j  λ2 = -0.907-3.535j
# Fixed points calculated!
# Fixed point at (-12.7521, -22.331) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.904+3.550j  λ2 = -0.904-3.550j
# Fixed points calculated!
# Fixed point at (-12.7321, -22.2841) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.902+3.565j  λ2 = -0.902-3.565j
# Fixed points calculated!
# Fixed point at (-12.7123, -22.2373) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.899+3.581j  λ2 = -0.899-3.581j
# Fixed points calculated!
# Fixed point at (-12.6926, -22.1907) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.897+3.596j  λ2 = -0.897-3.596j
# Fixed points calculated!
# Fixed point at (-12.673, -22.1442) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.894+3.611j  λ2 = -0.894-3.611j
# Fixed points calculated!
# Fixed point at (-12.6536, -22.0979) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.892+3.626j  λ2 = -0.892-3.626j
# Fixed points calculated!
# Fixed point at (-12.6343, -22.0518) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.889+3.641j  λ2 = -0.889-3.641j
# Fixed points calculated!
# Fixed point at (-12.6152, -22.0058) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.887+3.656j  λ2 = -0.887-3.656j
# Fixed points calculated!
# Fixed point at (-12.5961, -21.96) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.885+3.670j  λ2 = -0.885-3.670j
# Fixed points calculated!
# Fixed point at (-12.5773, -21.9143) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.882+3.685j  λ2 = -0.882-3.685j
# Fixed points calculated!
# Fixed point at (-12.5585, -21.8688) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.880+3.700j  λ2 = -0.880-3.700j
# Fixed points calculated!
# Fixed point at (-12.5399, -21.8234) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.877+3.715j  λ2 = -0.877-3.715j
# Fixed points calculated!
# Fixed point at (-12.5214, -21.7782) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.875+3.729j  λ2 = -0.875-3.729j
# Fixed points calculated!
# Fixed point at (-12.5031, -21.7332) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.873+3.744j  λ2 = -0.873-3.744j
# Fixed points calculated!
# Fixed point at (-12.4848, -21.6883) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.870+3.758j  λ2 = -0.870-3.758j
# Fixed points calculated!
# Fixed point at (-12.4667, -21.6435) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.868+3.773j  λ2 = -0.868-3.773j
# Fixed points calculated!
# Fixed point at (-12.4487, -21.5989) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.866+3.787j  λ2 = -0.866-3.787j
# Fixed points calculated!
# Fixed point at (-12.4309, -21.5545) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.863+3.802j  λ2 = -0.863-3.802j
# Fixed points calculated!
# Fixed point at (-12.4131, -21.5102) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.861+3.816j  λ2 = -0.861-3.816j
# Fixed points calculated!
# Fixed point at (-12.3955, -21.466) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.859+3.831j  λ2 = -0.859-3.831j
# Fixed points calculated!
# Fixed point at (-12.378, -21.422) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.856+3.845j  λ2 = -0.856-3.845j
# Fixed points calculated!
# Fixed point at (-12.3606, -21.3781) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.854+3.859j  λ2 = -0.854-3.859j
# Fixed points calculated!
# Fixed point at (-12.3433, -21.3344) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.852+3.873j  λ2 = -0.852-3.873j
# Fixed points calculated!
# Fixed point at (-12.3261, -21.2908) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.850+3.887j  λ2 = -0.850-3.887j
# Fixed points calculated!
# Fixed point at (-12.309, -21.2474) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.847+3.902j  λ2 = -0.847-3.902j
# Fixed points calculated!
# Fixed point at (-12.2921, -21.2041) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.845+3.916j  λ2 = -0.845-3.916j
# Fixed points calculated!
# Fixed point at (-12.2752, -21.1609) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.843+3.930j  λ2 = -0.843-3.930j
# Fixed points calculated!
# Fixed point at (-12.2585, -21.1179) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.841+3.944j  λ2 = -0.841-3.944j
# Fixed points calculated!
# Fixed point at (-12.2418, -21.075) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.838+3.958j  λ2 = -0.838-3.958j
# Fixed points calculated!
# Fixed point at (-12.2253, -21.0322) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.836+3.972j  λ2 = -0.836-3.972j
# Fixed points calculated!
# Fixed point at (-12.2088, -20.9896) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.834+3.985j  λ2 = -0.834-3.985j
# Fixed points calculated!
# Fixed point at (-12.1925, -20.9471) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.832+3.999j  λ2 = -0.832-3.999j
# Fixed points calculated!
# Fixed point at (-12.1763, -20.9048) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.830+4.013j  λ2 = -0.830-4.013j
# Fixed points calculated!
# Fixed point at (-12.1601, -20.8625) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.828+4.027j  λ2 = -0.828-4.027j
# Fixed points calculated!
# Fixed point at (-12.1441, -20.8205) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.825+4.040j  λ2 = -0.825-4.040j
# Fixed points calculated!
# Fixed point at (-12.1281, -20.7785) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.823+4.054j  λ2 = -0.823-4.054j
# Fixed points calculated!
# Fixed point at (-12.1123, -20.7367) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.821+4.068j  λ2 = -0.821-4.068j
# Fixed points calculated!
# Fixed point at (-12.0965, -20.695) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.819+4.081j  λ2 = -0.819-4.081j
# Fixed points calculated!
# Fixed point at (-12.0809, -20.6534) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.817+4.095j  λ2 = -0.817-4.095j
# Fixed points calculated!
# Fixed point at (-12.0653, -20.612) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.815+4.108j  λ2 = -0.815-4.108j
# Fixed points calculated!
# Fixed point at (-12.0498, -20.5706) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.813+4.122j  λ2 = -0.813-4.122j
# Fixed points calculated!
# Fixed point at (-12.0345, -20.5294) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.811+4.135j  λ2 = -0.811-4.135j
# Fixed points calculated!
# Fixed point at (-12.0192, -20.4884) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.809+4.149j  λ2 = -0.809-4.149j
# Fixed points calculated!
# Fixed point at (-12.0039, -20.4474) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.807+4.162j  λ2 = -0.807-4.162j
# Fixed points calculated!
# Fixed point at (-11.9888, -20.4066) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.805+4.175j  λ2 = -0.805-4.175j
# Fixed points calculated!
# Fixed point at (-11.9738, -20.3659) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.803+4.189j  λ2 = -0.803-4.189j
# Fixed points calculated!
# Fixed point at (-11.9588, -20.3253) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.801+4.202j  λ2 = -0.801-4.202j
# Fixed points calculated!
# Fixed point at (-11.944, -20.2849) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.798+4.215j  λ2 = -0.798-4.215j
# Fixed points calculated!
# Fixed point at (-11.9292, -20.2445) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.796+4.228j  λ2 = -0.796-4.228j
# Fixed points calculated!
# Fixed point at (-11.9145, -20.2043) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.794+4.241j  λ2 = -0.794-4.241j
# Fixed points calculated!
# Fixed point at (-11.8998, -20.1642) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.792+4.254j  λ2 = -0.792-4.254j
# Fixed points calculated!
# Fixed point at (-11.8853, -20.1242) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.790+4.267j  λ2 = -0.790-4.267j
# Fixed points calculated!
# Fixed point at (-11.8708, -20.0843) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.788+4.280j  λ2 = -0.788-4.280j
# Fixed points calculated!
# Fixed point at (-11.8565, -20.0446) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.787+4.293j  λ2 = -0.787-4.293j
# Fixed points calculated!
# Fixed point at (-11.8421, -20.005) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.785+4.306j  λ2 = -0.785-4.306j
# Fixed points calculated!
# Fixed point at (-11.8279, -19.9654) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.783+4.319j  λ2 = -0.783-4.319j
# Fixed points calculated!
# Fixed point at (-11.8138, -19.926) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.781+4.332j  λ2 = -0.781-4.332j
# Fixed points calculated!
# Fixed point at (-11.7997, -19.8867) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.779+4.345j  λ2 = -0.779-4.345j
# Fixed points calculated!
# Fixed point at (-11.7857, -19.8475) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.777+4.358j  λ2 = -0.777-4.358j
# Fixed points calculated!
# Fixed point at (-11.7717, -19.8084) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.775+4.370j  λ2 = -0.775-4.370j
# Fixed points calculated!
# Fixed point at (-11.7579, -19.7695) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.773+4.383j  λ2 = -0.773-4.383j
# Fixed points calculated!
# Fixed point at (-11.7441, -19.7306) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.771+4.396j  λ2 = -0.771-4.396j
# Fixed points calculated!
# Fixed point at (-11.7304, -19.6919) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.769+4.408j  λ2 = -0.769-4.408j
# Fixed points calculated!
# Fixed point at (-11.7167, -19.6532) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.767+4.421j  λ2 = -0.767-4.421j
# Fixed points calculated!
# Fixed point at (-11.7032, -19.6147) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.765+4.434j  λ2 = -0.765-4.434j
# Fixed points calculated!
# Fixed point at (-11.6897, -19.5763) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.763+4.446j  λ2 = -0.763-4.446j
# Fixed points calculated!
# Fixed point at (-11.6762, -19.5379) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.762+4.459j  λ2 = -0.762-4.459j
# Fixed points calculated!
# Fixed point at (-11.6629, -19.4997) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.760+4.471j  λ2 = -0.760-4.471j
# Fixed points calculated!
# Fixed point at (-11.6496, -19.4616) --> Stable Spiral Focus Point  :: Eigen Values: λ1 = -0.758+4.484j  λ2 = -0.758-4.484j

# %%
Iet_seq = (Imin + np.arange(0, Isteps) / Isteps * (Imax - Imin)) / params['gamma']

plt.figure(figsize=(6,2))

for k in range(Isteps):
    fixed_point = fixedTrack[k]
    fixed_color = fixedColors[k]

    for fp, color in zip(fixed_point, fixed_color):
        plt.scatter(Iet_seq[k], fp[0], marker='.', c = color)

plt.ylim([-25, 0]); plt.xlim([Imin / params['gamma'], Imax / params['gamma']])
plt.xlabel(r'$I_{e}(t)$'); plt.ylabel(r'$U_e$')
plt.title(f"Stable point(s) as a function of external current \n\u03C3e = {params['sigmaE']}mV, \u03C3i = {params['sigmaI']}mV")
plt.grid()

# %%
# Plotting

params['ie0'] = Imin
gradx1, gradx2, _, _, tempfp = findFixedPoints(minval=-1, maxval=1, resolution=75, **params)
extSeq, inhSeq = plotVectField(tspan, tempfp, (10, 10), 5, [x1, x2], [gradx1, gradx2], -1, 1, params['gamma'], **params)
plotTimeSeries(extSeq, inhSeq, tspan, size = (10, 5))
# Out:
# /tmp/ipykernel_397246/3131282832.py:3: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-beta * gamma * (x - theta)))
# Fixed points calculated!
# Evaluating with random initialization No. 1 --> Execution time: 0.706s
# Evaluating with random initialization No. 2 --> Execution time: 0.707s
# Evaluating with random initialization No. 3 --> Execution time: 0.707s
# Evaluating with random initialization No. 4 --> Execution time: 0.707s
# Evaluating with random initialization No. 5 --> Execution time: 0.706s

# %%
params['ie0'] = Iet_seq[100] * params['gamma']
gradx1, gradx2, _, _, tempfp = findFixedPoints(minval=-1, maxval=1, resolution=75, **params)
extSeq, inhSeq = plotVectField(tspan, tempfp, (10, 10), 5, [x1, x2], [gradx1, gradx2], -1, 1, params['gamma'], **params)
plotTimeSeries(extSeq, inhSeq, tspan, size = (10, 5))
# Out:
# /tmp/ipykernel_397246/3131282832.py:3: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-beta * gamma * (x - theta)))
# Fixed points calculated!
# Evaluating with random initialization No. 1 --> Execution time: 0.715s
# Evaluating with random initialization No. 2 --> Execution time: 0.713s
# Evaluating with random initialization No. 3 --> Execution time: 0.710s
# Evaluating with random initialization No. 4 --> Execution time: 0.707s
# Evaluating with random initialization No. 5 --> Execution time: 0.711s

# %%
params['ie0'] = Iet_seq[249] * params.get('gamma')
gradx1, gradx2, _, _, tempfp = findFixedPoints(minval=-1, maxval=1, resolution=75, **params)
extSeq, inhSeq = plotVectField(tspan, tempfp, (10, 10), 5, [x1, x2], [gradx1, gradx2], -1, 1, params['gamma'], **params)
plotTimeSeries(extSeq, inhSeq, tspan, size = (10, 5))
# Out:
# /tmp/ipykernel_397246/3131282832.py:3: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-beta * gamma * (x - theta)))
# Fixed points calculated!
# Evaluating with random initialization No. 1 --> Execution time: 0.709s
# Evaluating with random initialization No. 2 --> Execution time: 0.715s
# Evaluating with random initialization No. 3 --> Execution time: 0.710s
# Evaluating with random initialization No. 4 --> Execution time: 0.715s
# Evaluating with random initialization No. 5 --> Execution time: 0.706s
